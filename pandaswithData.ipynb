# %%
import pandas as pd
import numpy as np

# %%
car_sales = pd.read_csv("data\\car-sales.csv") # if csv file is in same folder then remove 'data\\'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales["Price"].dtype # answer = dtype('O'), this is often used when the data in a column is not of a standard numeric or string type, but rather a more complex or mixed type.
# Out:
# dtype('O')

# %%
car_sales["Price"] = car_sales["Price"].replace("[$,.]", "",regex=True).astype(int)

# %%
car_sales['Price']
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int64

# %%
car_sales['Make'] = car_sales['Make'].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000
# 5  TOYOTA  Green          99213      4   450000
# 6   HONDA   Blue          45698      4   750000
# 7   HONDA   Blue          54738      4   700000
# 8  TOYOTA  White          60000      4   625000
# 9  NISSAN  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("data\\car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.describe()
# Out:
#             Odometer  Doors
# count      10.000000    9.0
# mean    92302.666667    4.0
# std     57012.134647    0.5
# min     11179.000000    3.0
# 25%     66974.750000    4.0
# 50%     92302.666667    4.0
# 75%     92302.666667    4.0
# max    213095.000000    5.0

# %%
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  10 non-null     float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales_missing.isnull()
# Out:
#     Make  Colour  Odometer  Doors  Price
# 0  False   False     False  False  False
# 1  False   False     False  False  False
# 2  False   False     False  False  False
# 3  False   False     False  False  False
# 4  False   False     False  False  False
# 5  False   False     False  False  False
# 6  False    True     False  False  False
# 7  False   False     False  False   True
# 8  False   False     False   True   True
# 9   True   False     False  False  False

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000
# 5  TOYOTA  Green          99213      4   450000
# 6   HONDA   Blue          45698      4   750000
# 7   HONDA   Blue          54738      4   700000
# 8  TOYOTA  White          60000      4   625000
# 9  NISSAN  White          31600      4   970000

# %%
seats = pd.Series([5,5,5,5,5])
car_sales['Seats'] = seats
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  TOYOTA  White         150043      4   400000    5.0
# 1   HONDA    Red          87899      4   500000    5.0
# 2  TOYOTA   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  NISSAN  White         213095      4   350000    5.0
# 5  TOYOTA  Green          99213      4   450000    NaN
# 6   HONDA   Blue          45698      4   750000    NaN
# 7   HONDA   Blue          54738      4   700000    NaN
# 8  TOYOTA  White          60000      4   625000    NaN
# 9  NISSAN  White          31600      4   970000    NaN

# %%
car_sales['Seats'].fillna(value=5,inplace=True)
# Out:
# C:\Users\Nirav\AppData\Local\Temp\ipykernel_12376\2058951913.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales['Seats'].fillna(value=5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  TOYOTA  White         150043      4   400000    5.0
# 1   HONDA    Red          87899      4   500000    5.0
# 2  TOYOTA   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  NISSAN  White         213095      4   350000    5.0
# 5  TOYOTA  Green          99213      4   450000    5.0
# 6   HONDA   Blue          45698      4   750000    5.0
# 7   HONDA   Blue          54738      4   700000    5.0
# 8  TOYOTA  White          60000      4   625000    5.0
# 9  NISSAN  White          31600      4   970000    5.0

# %%
fuel_economy =pd.Series([3.0,4,5,6,3,4,7.6,3.3,4.5])
car_sales["Fuel PER 100KM"]=fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel PER 100KM
# 0  TOYOTA  White         150043      4   400000    5.0             3.0
# 1   HONDA    Red          87899      4   500000    5.0             4.0
# 2  TOYOTA   Blue          32549      3   700000    5.0             5.0
# 3     BMW  Black          11179      5  2200000    5.0             6.0
# 4  NISSAN  White         213095      4   350000    5.0             3.0
# 5  TOYOTA  Green          99213      4   450000    5.0             4.0
# 6   HONDA   Blue          45698      4   750000    5.0             7.6
# 7   HONDA   Blue          54738      4   700000    5.0             3.3
# 8  TOYOTA  White          60000      4   625000    5.0             4.5
# 9  NISSAN  White          31600      4   970000    5.0             NaN

# %%
car_sales['Price'] = car_sales['Price'].astype(str)
car_sales['Price'] = car_sales['Price'].str.replace(r'0$', '', regex=True)

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales['Price']
# Out:
# 0     40000
# 1     50000
# 2     70000
# 3    220000
# 4     35000
# 5     45000
# 6     75000
# 7     70000
# 8     62500
# 9     97000
# Name: Price, dtype: object

# %%
car_sales['Price'] = car_sales['Price'].astype(int)

# %%
car_sales['Total Fuel Used'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel PER 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel PER 100KM  \
# 0  TOYOTA  White         150043      4   40000    5.0             3.0
# 1   HONDA    Red          87899      4   50000    5.0             4.0
# 2  TOYOTA   Blue          32549      3   70000    5.0             5.0
# 3     BMW  Black          11179      5  220000    5.0             6.0
# 4  NISSAN  White         213095      4   35000    5.0             3.0
# 5  TOYOTA  Green          99213      4   45000    5.0             4.0
# 6   HONDA   Blue          45698      4   75000    5.0             7.6
# 7   HONDA   Blue          54738      4   70000    5.0             3.3
# 8  TOYOTA  White          60000      4   62500    5.0             4.5
# 9  NISSAN  White          31600      4   97000    5.0             NaN
#
#    Total Fuel Used
# 0         4501.290
# 1         3515.960
# 2         1627.450
# 3          670.740
# 4         6392.850
# 5         3968.520
# 6         3473.048
# 7         1806.354
# ...

# %%
car_sales['Total Fuel Used'] = car_sales['Total Fuel Used'].astype(float).round(2)
car_sales['Total Fuel Used']
# Out:
# 0    4501.29
# 1    3515.96
# 2    1627.45
# 3     670.74
# 4    6392.85
# 5    3968.52
# 6    3473.05
# 7    1806.35
# 8    2700.00
# 9        NaN
# Name: Total Fuel Used, dtype: float64

# %%
car_sales["NumberOfTyre"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel PER 100KM  \
# 0  TOYOTA  White         150043      4   40000    5.0             3.0
# 1   HONDA    Red          87899      4   50000    5.0             4.0
# 2  TOYOTA   Blue          32549      3   70000    5.0             5.0
# 3     BMW  Black          11179      5  220000    5.0             6.0
# 4  NISSAN  White         213095      4   35000    5.0             3.0
# 5  TOYOTA  Green          99213      4   45000    5.0             4.0
# 6   HONDA   Blue          45698      4   75000    5.0             7.6
# 7   HONDA   Blue          54738      4   70000    5.0             3.3
# 8  TOYOTA  White          60000      4   62500    5.0             4.5
# 9  NISSAN  White          31600      4   97000    5.0             NaN
#
#    Total Fuel Used  NumberOfTyre
# 0          4501.29             4
# 1          3515.96             4
# 2          1627.45             4
# 3           670.74             4
# ...

# %%
car_sales['Passed Road Saftey'] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel PER 100KM  \
# 0  TOYOTA  White         150043      4   40000    5.0             3.0
# 1   HONDA    Red          87899      4   50000    5.0             4.0
# 2  TOYOTA   Blue          32549      3   70000    5.0             5.0
# 3     BMW  Black          11179      5  220000    5.0             6.0
# 4  NISSAN  White         213095      4   35000    5.0             3.0
# 5  TOYOTA  Green          99213      4   45000    5.0             4.0
# 6   HONDA   Blue          45698      4   75000    5.0             7.6
# 7   HONDA   Blue          54738      4   70000    5.0             3.3
# 8  TOYOTA  White          60000      4   62500    5.0             4.5
# 9  NISSAN  White          31600      4   97000    5.0             NaN
#
#    Total Fuel Used  NumberOfTyre  Passed Road Saftey
# 0          4501.29             4                True
# 1          3515.96             4                True
# ...

# %%
car_sales.to_csv('new_car_sales',index=False, encoding='utf-8')

# %%
import pandas as pd
car_sales = pd.read_csv("data\\car-sales-extended-missing-data.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales.isnull()
# Out:
#       Make  Colour  Odometer (KM)  Doors  Price
# 0    False   False          False  False  False
# 1    False   False          False  False  False
# 2    False   False          False  False  False
# 3    False   False          False  False  False
# 4    False   False          False  False  False
# ..     ...     ...            ...    ...    ...
# 995  False   False          False  False  False
# 996   True   False          False  False  False
# 997  False   False          False  False  False
# 998  False   False          False  False  False
# 999  False   False          False  False  False
#
# [1000 rows x 5 columns]

# %%
car_sales.isnull().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
car_sales.dropna(subset=['Make'], inplace=True)
car_sales.isnull().sum()
# Out:
# Make              0
# Colour           49
# Odometer (KM)    48
# Doors            48
# Price            48
# dtype: int64

# %%
car_sales['Colour'].fillna(car_sales['Colour'].mode()[0], inplace=True)
car_sales.isnull().sum()
# Out:
# Make              0
# Colour            0
# Odometer (KM)    48
# Doors            48
# Price            48
# dtype: int64

# %%
car_sales['Odometer (KM)'].fillna(car_sales['Odometer (KM)'].mean(),inplace=True)
car_sales.isnull().sum()
# Out:
# C:\Users\Nirav\AppData\Local\Temp\ipykernel_13724\931480677.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales['Odometer (KM)'].fillna(car_sales['Odometer (KM)'].mean(),inplace=True)
# Make              0
# Colour            0
# Odometer (KM)     0
# Doors            48
# Price            48
# dtype: int64

# %%
car_sales.fillna( {'Doors': 5}, inplace=True)
car_sales.isnull().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
# car_sales['Price'].fillna(car_sales['Price'].mean(), inplace=True)
car_sales.fillna({'Price' :car_sales['Price'].mean() }, inplace = True) # this is better way 
car_sales.isnull().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
print(car_sales.to_string())
# Out:
#        Make Colour  Odometer (KM)  Doors         Price
# 0     Honda  White   35431.000000    4.0  15323.000000
# 1       BMW   Blue  192714.000000    5.0  19943.000000
# 2     Honda  White   84714.000000    4.0  28343.000000
# 3    Toyota  White  154365.000000    4.0  13434.000000
# 4    Nissan   Blue  181577.000000    3.0  14043.000000
# 5     Honda    Red   42652.000000    4.0  23883.000000
# 6    Toyota   Blue  163453.000000    4.0   8473.000000
# 7     Honda  White  131958.988926    4.0  20306.000000
# 9     Honda   Blue   51029.000000    4.0  26683.000000
# 10   Nissan  White  167421.000000    4.0  16259.000000
# 11   Nissan  Green   17119.000000    4.0   6160.000000
# 12   Nissan  White  102303.000000    4.0  16909.000000
# 14    Honda   Blue  199833.000000    4.0  18946.000000
# 15   Toyota   Blue  205592.000000    4.0  16290.000000
# 16   Toyota    Red   96742.000000    4.0  34465.000000
# 17      BMW  White  194189.000000    5.0  17177.000000
# ...

# %%
car_sales['Odometer (KM)']=car_sales['Odometer (KM)'].astype(float).round(2)
car_sales['Price']=car_sales['Price'].astype(float).round(2)

# %%
car_sales['Odometer (KM)']
# Out:
# 0       35431.0
# 1      192714.0
# 2       84714.0
# 3      154365.0
# 4      181577.0
#          ...
# 994    163322.0
# 995     35820.0
# 997     66604.0
# 998    215883.0
# 999    248360.0
# Name: Odometer (KM), Length: 951, dtype: float64

# %%
print(car_sales.to_string())
# Out:
#        Make Colour  Odometer (KM)  Doors     Price
# 0     Honda  White       35431.00    4.0  15323.00
# 1       BMW   Blue      192714.00    5.0  19943.00
# 2     Honda  White       84714.00    4.0  28343.00
# 3    Toyota  White      154365.00    4.0  13434.00
# 4    Nissan   Blue      181577.00    3.0  14043.00
# 5     Honda    Red       42652.00    4.0  23883.00
# 6    Toyota   Blue      163453.00    4.0   8473.00
# 7     Honda  White      131958.99    4.0  20306.00
# 9     Honda   Blue       51029.00    4.0  26683.00
# 10   Nissan  White      167421.00    4.0  16259.00
# 11   Nissan  Green       17119.00    4.0   6160.00
# 12   Nissan  White      102303.00    4.0  16909.00
# 14    Honda   Blue      199833.00    4.0  18946.00
# 15   Toyota   Blue      205592.00    4.0  16290.00
# 16   Toyota    Red       96742.00    4.0  34465.00
# 17      BMW  White      194189.00    5.0  17177.00
# 18   Nissan  White       67991.00    3.0   9109.00
# ...

# %%
car_sales.isnull().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
car_sales['Seats'] = 5
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0   Honda  White        35431.0    4.0  15323.0      5
# 1     BMW   Blue       192714.0    5.0  19943.0      5
# 2   Honda  White        84714.0    4.0  28343.0      5
# 3  Toyota  White       154365.0    4.0  13434.0      5
# 4  Nissan   Blue       181577.0    3.0  14043.0      5

# %%
import numpy as np
car_sales["Fuel range"] = np.random.uniform(3,6, size=len(car_sales)).astype(float).round(2)
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel range
# 0   Honda  White        35431.0    4.0  15323.0      5        5.38
# 1     BMW   Blue       192714.0    5.0  19943.0      5        3.89
# 2   Honda  White        84714.0    4.0  28343.0      5        3.72
# 3  Toyota  White       154365.0    4.0  13434.0      5        4.28
# 4  Nissan   Blue       181577.0    3.0  14043.0      5        4.49

# %%
car_sales['Total Fuel Used'] = car_sales['Odometer (KM)']/car_sales['Fuel range']
car_sales['Total Fuel Used'] = car_sales['Total Fuel Used'].astype(float).round(2)

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel range  \
# 0   Honda  White        35431.0    4.0  15323.0      5        5.38
# 1     BMW   Blue       192714.0    5.0  19943.0      5        3.89
# 2   Honda  White        84714.0    4.0  28343.0      5        3.72
# 3  Toyota  White       154365.0    4.0  13434.0      5        4.28
# 4  Nissan   Blue       181577.0    3.0  14043.0      5        4.49
#
#    Total Fuel Used
# 0          6585.69
# 1         49540.87
# 2         22772.58
# 3         36066.59
# 4         40440.31

# %%
car_sales.rename(columns={'Fuel range': 'Fuel Milage'}, inplace=True)
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Milage  \
# 0   Honda  White        35431.0    4.0  15323.0      5         5.38
# 1     BMW   Blue       192714.0    5.0  19943.0      5         3.89
# 2   Honda  White        84714.0    4.0  28343.0      5         3.72
# 3  Toyota  White       154365.0    4.0  13434.0      5         4.28
# 4  Nissan   Blue       181577.0    3.0  14043.0      5         4.49
#
#    Total Fuel Used
# 0          6585.69
# 1         49540.87
# 2         22772.58
# 3         36066.59
# 4         40440.31

# %%
car_sales['Make'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# Count how many cars of each make
make_counts = car_sales['Make'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(make_counts, labels=make_counts.index, autopct='%1.1f%%', startangle=140, 
        wedgeprops={'edgecolor': 'white'}, textprops={'fontsize': 12})

plt.title('Distribution of Car Makes', fontsize=16)
plt.axis('equal')  # Keeps the pie chart circular
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data (adjust path and format)
df = car_sales  

# 1. Bar Plot: Average Price by Make
avg_price = df.groupby('Make')['Price'].mean()
avg_price.plot(kind='bar', title='Average Price by Make', figsize=(10, 6))
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# 2. Pie Chart: Colour Distribution
df['Colour'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Colour Distribution', figsize=(8, 8))
plt.ylabel('')
plt.show()

# 3. Histogram: Odometer Readings
df['Odometer (KM)'].plot(kind='hist', bins=20, title='Odometer Reading Distribution', figsize=(10, 6))
plt.xlabel('KM')
plt.show()

# 4. Scatter Plot: Price vs Odometer
plt.figure(figsize=(10, 6))
plt.scatter(df['Odometer (KM)'], df['Price'], alpha=0.5)
plt.title('Price vs Odometer')
plt.xlabel('Odometer (KM)')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# 5. Box Plot: Fuel Mileage by Number of Seats
df.boxplot(column='Fuel Milage', by='Seats', figsize=(10, 6))
plt.title('Fuel Mileage by Seats')
plt.suptitle('')
plt.xlabel('Seats')
plt.ylabel('Fuel Mileage')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import squarify


# Group data by 'Make' and count occurrences
make_counts = df['Make'].value_counts()

# Treemap Plot
plt.figure(figsize=(12, 8))
squarify.plot(sizes=make_counts.values, label=make_counts.index, alpha=0.8)
plt.title('Car Distribution by Make')
plt.axis('off')
plt.show()

# %%
grouped = df.groupby(['Make', 'Colour']).size().sort_values(ascending=False).head(20)

# Extract sizes and labels
sizes = grouped.values
labels = [f"{make}\n{colour}\n{count}" for (make, colour), count in grouped.items()]
colours = [colour for (_, colour) in grouped.index]

# Map common colour names to matplotlib-recognized colors (simple fallback)
# You may want to refine this mapping based on your dataset
import matplotlib.colors as mcolors

def clean_color(c):
    c = c.lower()
    # Handle some common alternates
    color_map = {
        'silver': 'silver',
        'grey': 'gray',
        'gray': 'gray',
        'black': 'black',
        'white': 'white',
        'blue': 'blue',
        'red': 'red',
        'green': 'green',
        'yellow': 'yellow',
        'gold': 'gold',
        'brown': 'saddlebrown',
        'orange': 'orange',
        'beige': 'wheat',
        'purple': 'purple',
        'maroon': 'maroon'
    }
    return color_map.get(c, 'lightgrey')  # default fallback

color_values = [clean_color(c) for c in colours]

# Create the treemap
plt.figure(figsize=(14, 8))
squarify.plot(sizes=sizes, label=labels, color=color_values, alpha=0.85)
plt.title("Top 20 Make + Colour Combinations", fontsize=16)
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
print(df.to_string())
# Out:
#        Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel Milage  Total Fuel Used
# 0     Honda  White       35431.00    4.0  15323.00      5         5.38          6585.69
# 1       BMW   Blue      192714.00    5.0  19943.00      5         3.89         49540.87
# 2     Honda  White       84714.00    4.0  28343.00      5         3.72         22772.58
# 3    Toyota  White      154365.00    4.0  13434.00      5         4.28         36066.59
# 4    Nissan   Blue      181577.00    3.0  14043.00      5         4.49         40440.31
# 5     Honda    Red       42652.00    4.0  23883.00      5         4.23         10083.22
# 6    Toyota   Blue      163453.00    4.0   8473.00      5         5.51         29664.79
# 7     Honda  White      131958.99    4.0  20306.00      5         5.73         23029.49
# 9     Honda   Blue       51029.00    4.0  26683.00      5         4.30         11867.21
# 10   Nissan  White      167421.00    4.0  16259.00      5         4.79         34952.19
# ...

# %%
price_col = df.pop('Price')      # Remove 'Price' from current position
df['Price'] = price_col  
print(df.to_string())
# Out:
#        Make Colour  Odometer (KM)  Doors  Seats  Fuel Milage  Total Fuel Used     Price
# 0     Honda  White       35431.00    4.0      5         5.38          6585.69  15323.00
# 1       BMW   Blue      192714.00    5.0      5         3.89         49540.87  19943.00
# 2     Honda  White       84714.00    4.0      5         3.72         22772.58  28343.00
# 3    Toyota  White      154365.00    4.0      5         4.28         36066.59  13434.00
# 4    Nissan   Blue      181577.00    3.0      5         4.49         40440.31  14043.00
# 5     Honda    Red       42652.00    4.0      5         4.23         10083.22  23883.00
# 6    Toyota   Blue      163453.00    4.0      5         5.51         29664.79   8473.00
# 7     Honda  White      131958.99    4.0      5         5.73         23029.49  20306.00
# 9     Honda   Blue       51029.00    4.0      5         4.30         11867.21  26683.00
# 10   Nissan  White      167421.00    4.0      5         4.79         34952.19  16259.00
# ...

# %%
df.to_csv('cardataformodel.csv',index=False, encoding='utf-8' )

# %%
import pandas as pd

# %%
df = pd.read_csv("data\\HDFC.csv")


df.head()
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03   HDFC     EQ      271.75  293.5  293.50  293.5  293.5  293.50
# 1  2000-01-04   HDFC     EQ      293.50  317.0  317.00  297.0  304.0  304.05
# 2  2000-01-05   HDFC     EQ      304.05  290.0  303.90  285.0  295.0  292.80
# 3  2000-01-06   HDFC     EQ      292.80  301.0  314.00  295.0  296.0  296.45
# 4  2000-01-07   HDFC     EQ      296.45  290.0  296.35  281.0  287.1  286.55
#
#      VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  293.50   22744  6.675364e+11     NaN                 NaN          NaN
# 1  303.62  255251  7.749972e+12     NaN                 NaN          NaN
# 2  294.53  269087  7.925368e+12     NaN                 NaN          NaN
# 3  300.14  305916  9.181669e+12     NaN                 NaN          NaN
# 4  288.80  197039  5.690480e+12     NaN                 NaN          NaN

# %%
df.tail()
# Out:
#             Date Symbol Series  Prev Close     Open    High      Low     Last  \
# 5301  2021-04-26   HDFC     EQ     2497.35  2500.00  2534.1  2483.20  2502.00
# 5302  2021-04-27   HDFC     EQ     2509.80  2494.15  2526.8  2486.25  2514.00
# 5303  2021-04-28   HDFC     EQ     2518.40  2516.10  2609.0  2508.30  2575.00
# 5304  2021-04-29   HDFC     EQ     2577.00  2590.90  2628.0  2533.00  2539.70
# 5305  2021-04-30   HDFC     EQ     2538.85  2503.10  2525.0  2411.10  2433.25
#
#         Close     VWAP   Volume      Turnover    Trades  Deliverable Volume  \
# 5301  2509.80  2508.07  3916088  9.821805e+14  121028.0           2440395.0
# 5302  2518.40  2509.18  2040799  5.120730e+14  102250.0           1040749.0
# 5303  2577.00  2574.21  3407461  8.771527e+14  117425.0           1815110.0
# 5304  2538.85  2569.65  3005468  7.722995e+14  132826.0           1472924.0
# 5305  2420.10  2445.94  6024595  1.473581e+15  224454.0           3839105.0
#
#       %Deliverble
# 5301       0.6232
# ...

# %%
print(df.describe())
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1283.666114  1284.393074  1304.269732  1263.297842  1283.885017
# std     709.395090   709.703665   721.308080   697.450309   709.250204
# min     271.750000   284.000000   290.500000   273.250000   282.850000
# 25%     668.650000   669.712500   677.512500   660.000000   669.000000
# 50%    1136.275000  1135.400000  1156.725000  1119.000000  1135.000000
# 75%    1811.475000  1813.812500  1835.000000  1783.075000  1812.000000
# max    3180.150000  3148.000000  3262.000000  3100.550000  3178.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1284.071005  1283.664578  1.848187e+06  2.620759e+14  102159.051303
# std     709.430515   709.109622  2.991387e+06  3.607844e+14   57948.603200
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %%
df = df.drop(['Trades','Deliverable Volume','%Deliverble'], axis=1)
df.head()
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03   HDFC     EQ      271.75  293.5  293.50  293.5  293.5  293.50
# 1  2000-01-04   HDFC     EQ      293.50  317.0  317.00  297.0  304.0  304.05
# 2  2000-01-05   HDFC     EQ      304.05  290.0  303.90  285.0  295.0  292.80
# 3  2000-01-06   HDFC     EQ      292.80  301.0  314.00  295.0  296.0  296.45
# 4  2000-01-07   HDFC     EQ      296.45  290.0  296.35  281.0  287.1  286.55
#
#      VWAP  Volume      Turnover
# 0  293.50   22744  6.675364e+11
# 1  303.62  255251  7.749972e+12
# 2  294.53  269087  7.925368e+12
# 3  300.14  305916  9.181669e+12
# 4  288.80  197039  5.690480e+12

# %%
df['Prev Close'].value_counts()
# Out:
# Prev Close
# 659.85     4
# 666.80     4
# 641.10     3
# 656.60     3
# 660.15     3
#           ..
# 2497.35    1
# 2509.80    1
# 2518.40    1
# 2577.00    1
# 302.20     1
# Name: count, Length: 4875, dtype: int64

# %%
low1 = int(input("Enter the low price:"))
df1 = df.apply(lambda row: row if row["Low"] <= low1 else None, axis = 1)
df1 = df1.dropna()
df1
# Out:
#            Date Symbol Series  Prev Close   Open    High     Low    Last  \
# 0    2000-01-03   HDFC     EQ      271.75  293.5  293.50  293.50  293.50
# 1    2000-01-04   HDFC     EQ      293.50  317.0  317.00  297.00  304.00
# 2    2000-01-05   HDFC     EQ      304.05  290.0  303.90  285.00  295.00
# 3    2000-01-06   HDFC     EQ      292.80  301.0  314.00  295.00  296.00
# 4    2000-01-07   HDFC     EQ      296.45  290.0  296.35  281.00  287.10
# 5    2000-01-10   HDFC     EQ      286.55  292.0  296.00  285.00  288.40
# 6    2000-01-11   HDFC     EQ      287.20  290.0  292.00  273.25  282.85
# 7    2000-01-12   HDFC     EQ      283.85  287.0  293.00  284.50  285.25
# 8    2000-01-13   HDFC     EQ      285.60  288.0  290.50  283.00  284.00
# 9    2000-01-14   HDFC     EQ      283.85  284.0  294.00  276.25  291.00
# 10   2000-01-17   HDFC     EQ      286.55  302.0  309.50  295.00  303.50
# 13   2000-01-20   HDFC     EQ      305.25  303.0  306.00  288.00  291.90
# ...

# %%
df.shape
# Out:
# (5306, 12)

# %%
df.dtypes
# Out:
# Date           object
# Symbol         object
# Series         object
# Prev Close    float64
# Open          float64
# High          float64
# Low           float64
# Last          float64
# Close         float64
# VWAP          float64
# Volume          int64
# Turnover      float64
# dtype: object

# %%
print(df['Close'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        293.50
# 1        304.05
# 2        292.80
# 3        296.45
# 4        286.55
#          ...
# 5301    2509.80
# 5302    2518.40
# 5303    2577.00
# 5304    2538.85
# 5305    2420.10
# Name: Close, Length: 5306, dtype: float64>

# %%
df_close_avg = df['Close'].mean()
print(df_close_avg)
# Out:
# 1284.0710045231813

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.plot(df[['Close', 'Prev Close']], linestyle = '-')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title("CLose and Prev CLose")
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month_Year'] = df['Date'].dt.to_period('M').astype(str)
monthly_avg_volume = df.groupby('Month_Year')['Volume'].mean()
plt.figure(figsize=(12, 6))
monthly_avg_volume.plot(kind='bar', color='skyblue')
plt.title('Monthly Average Volume')
plt.xlabel('Month-Year')
plt.ylabel('Average Volume')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month_Year'] = df['Date'].dt.to_period('M').astype(str)
df1 = df.groupby(['Month_Year'])['Volume'].mean()
print(df1)
# Out:
# Month_Year
# 2000-01    4.144694e+05
# 2000-02    6.519777e+05
# 2000-03    2.838909e+05
# 2000-04    4.530906e+05
# 2000-05    2.301468e+05
#                ...
# 2020-12    4.231120e+06
# 2021-01    4.622760e+06
# 2021-02    4.325175e+06
# 2021-03    3.802221e+06
# 2021-04    3.685433e+06
# Name: Volume, Length: 256, dtype: float64
